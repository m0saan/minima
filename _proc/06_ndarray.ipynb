# %% [raw]
# ---
# description: The NDArray class in minima is a kind of container that can hold all
#   sorts of elements, especially numbers (but for now just f32 numbers).
# output-file: ndarray.html
# title: ndarray
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import nbdev; nbdev.nbdev_export()
