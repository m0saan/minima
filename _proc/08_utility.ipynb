# %% [raw]
# ---
# description: utils for minima
# output-file: utility.html
# title: utility
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(prod)
# Out:
# ---
#
# [source](https://github.com/m0saan/minima/blob/main/minima/utility.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### prod
#
# >      prod (x)

# %% [markdown]
# ## Export

# %%
import nbdev; nbdev.nbdev_export()
